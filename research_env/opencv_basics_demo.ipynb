# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path

# %%
# reading images
filepath = str(Path("../imgs/beach.jpg"))
gray_scale_img = cv2.imread(filepath, 0)
rgb_scale_img = cv2.imread(filepath)
type(gray_scale_img)
# Out:
# numpy.ndarray

# %%
cv2.imshow("gray_scale_img", gray_scale_img)
cv2.imshow("rgb_scale_img", rgb_scale_img)
# to cose the opened images 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("gray_scale_img.jpg", gray_scale_img)
# Out:
# True

# %%
plt.imshow(gray_scale_img)  #cv2 reads in BGR format and matplotlib uses RGB

# %%
## Draw the shapes on images

# %%
rectangle_draw = cv2.rectangle(rgb_scale_img, (384,0),(510,128), (0,255,0),3)
cv2.imshow("rectangle_draw", rectangle_draw)
# to cose the opened images 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# adding text on image
font  = cv2.FONT_ITALIC
predicted_class = "Rectangle" # << from your model

rectangle_draw = cv2.rectangle(
    rgb_scale_img, (384, 0), (510, 128), (0, 255, 0), 3)
cv2.putText(rectangle_draw, predicted_class,
            (384+3, 0+30), font, 1, (0, 255, 0), 2)
cv2.imshow("rectangle_draw", rectangle_draw)
# to cose the opened images
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
font  = cv2.FONT_ITALIC


circle_draw = cv2.circle(
    rgb_scale_img, (500, 500), 100, (0, 150, 155), 3)
cv2.imshow("circle_draw", circle_draw)
# to cose the opened images
cv2.waitKey(0)
cv2.destroyAllWindows()
